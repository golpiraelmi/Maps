# %% [markdown]
# # Surficial Geology of Alberta, Generalized Digital Mosaic (DIG 2013-0002)

# %% [markdown]
# ### Source
# https://geology-ags-aer.opendata.arcgis.com/datasets/745bb49973194f46b19d5ad2f84afd61_0/data?geometry=161.284%2C45.024%2C-31.284%2C62.793

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import mapclassify
import pysal

# %%
df = gpd.read_file('/Users/golpira/Desktop/Surficial_Geology_of_Alberta,_Generalized_Digital_Mosaic_(DIG_2013-0002).geojson')

# %%
df.columns
# Out:
# Index(['FID', 'MAP_LABEL', 'GENETIC_GR', 'UNIT_DESC', 'TEXTURE', 'AGE', 'RGB',
#        'SHAPE_Length', 'SHAPE_Area', 'geometry'],
#       dtype='object')

# %%
df.shape
# Out:
# (18611, 10)

# %%
df.head(2)
# Out:
#    FID MAP_LABEL          GENETIC_GR  \
# 0    1         C  Colluvial Deposits
# 1    2         C  Colluvial Deposits
#
#                                            UNIT_DESC  \
# 0  Sediments that have reached their present posi...
# 1  Sediments that have reached their present posi...
#
#                                              TEXTURE       AGE         RGB  \
# 0  May contain pre-existing bedrock, till, glacio...  Holocene  153,102,51
# 1  May contain pre-existing bedrock, till, glacio...  Holocene  153,102,51
#
#    SHAPE_Length  SHAPE_Area                                           geometry
# 0      0.018680    0.000004  MULTIPOLYGON Z (((-113.74545 48.99758 0.00000,...
# 1      0.009882    0.000002  MULTIPOLYGON Z (((-113.67896 48.99758 0.00000,...

# %%
df = df[['MAP_LABEL','GENETIC_GR','AGE','RGB','SHAPE_Length','SHAPE_Area','geometry']]

# %%
df.head(2)
# Out:
#   MAP_LABEL          GENETIC_GR       AGE         RGB  SHAPE_Length  \
# 0         C  Colluvial Deposits  Holocene  153,102,51      0.018680
# 1         C  Colluvial Deposits  Holocene  153,102,51      0.009882
#
#    SHAPE_Area                                           geometry
# 0    0.000004  MULTIPOLYGON Z (((-113.74545 48.99758 0.00000,...
# 1    0.000002  MULTIPOLYGON Z (((-113.67896 48.99758 0.00000,...

# %%
# Unique entries in GENETIC_GR column
GENETIC_GR = list(df['GENETIC_GR'].unique()) 
GENETIC_GR
# Out:
# ['Colluvial Deposits',
#  'Eolian Deposits',
#  'Fluvial Deposits',
#  'Glaciofluvial Deposits',
#  'Lacustrine Deposits',
#  'Glaciolacustrine Deposits',
#  'Glaciers',
#  'Moraine',
#  'Fluted moraine',
#  'Stagnant Ice Moraine',
#  'Ice-thrust moraine',
#  'Organic Deposits',
#  'Bedrock',
#  'Preglacial Fluvial Deposits:']

# %% [markdown]
# ## Mapping

# %%
plt.figure(figsize=(10,15))
ax = df.plot(column='GENETIC_GR', legend=True)
ax.get_legend().set_bbox_to_anchor((1.4, 0.4))

x, y, arrow_length = 0.2, 0.2, 0.05
ax.annotate('N', xy=(x, y), xytext=(x, y-arrow_length),
            arrowprops=dict(facecolor='black', width=5, headwidth=15),
            ha='center', va='center', fontsize=25,
            xycoords=ax.transAxes)

plt.show()
